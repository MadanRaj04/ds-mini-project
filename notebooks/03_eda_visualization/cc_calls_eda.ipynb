# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('../../data/cleaned/cc_calls_cleaned.csv')
df.shape
# Out:
# (31406, 30)

# %%
df.head()
# Out:
#     call_date direction cc_care_package cc_care_package_discussed  \
# 0  2025-05-08  Outbound        Standard                       Yes
# 1  2024-11-25  Outbound        Standard                       Yes
# 2  2024-10-23   Inbound        Standard                       Yes
# 3  2025-01-13   Inbound         Premier                       Yes
# 4  2025-03-19   Inbound        Standard                       Yes
#
#   cc_urgency_getting_on_site cc_external_consultant  \
# 0                         No                     No
# 1                         No                     No
# 2                         No                     No
# 3                         No                     No
# 4                         No                     No
#
#   cc_agent_cross_sell_attempt cc_customer_issues_concerns  \
# 0                          No                         Yes
# 1                          No                         Yes
# 2                          No                         Yes
# 3                          No                         Yes
# 4                          No                         Yes
#
#   cc_business_struggles_financial_hardship cc_call_initiated_by  ...  \
# 0                                      Yes             Customer  ...
# 1                                       No                Agent  ...
# 2                                       No             Customer  ...
# 3                                      Yes             Customer  ...
# 4                                      Yes             Customer  ...
#
#   cc_contractor_sentiment_start_score cc_contractor_sentiment_end_score  \
# 0                                20.0                              30.0
# 1                                 0.0                               0.0
# 2                                20.0                              60.0
# 3                                20.0                              60.0
# 4                                20.0                              40.0
#
#   cc_contractor_sentiment_overall_score cc_contractor_sentiment_issues_score  \
# 0                                  30.0                                 20.0
# 1                                   0.0                                  0.0
# 2                                  40.0                                 20.0
# 3                                  40.0                                 30.0
# 4                                  40.0                                 20.0
#
#   cc_pricing_mentioned cc_pricing_sentiment_impact cc_refund_discussed  \
# 0                  Yes                         Yes                  No
# 1                  Yes                         Yes                  No
# 2                  Yes                         Yes                  No
# 3                  Yes                         Yes                 Yes
# 4                  Yes                         Yes                  No
#
#   cc_contractor_suggest_leave cc_contractor_complained  co_ref
# 0                         Yes                      Yes  HV3323
# 1                         Yes                      Yes  PJ7066
# 2                         Yes                      Yes  DP6030
# 3                         Yes                      Yes  AM2413
# 4                         Yes                      Yes  ED6707
#
# [5 rows x 30 columns]

# %% [markdown]
# Inbound vs Outbound calls

# %%
call_counts = df['direction'].value_counts()
call_counts
# Out:
# direction
# Outbound    24069
# Inbound      7337
# Name: count, dtype: int64

# %%
call_counts.plot(kind='bar', color=['red', 'blue'])
plt.title('Inbound vs Outbound Calls')
plt.xlabel('Call Direction')
plt.ylabel('Number of Calls')
plt.xticks(rotation=0)
plt.tight_layout()
plt.savefig('../../reports/figures/cc_01_call_direction.png')
plt.show()

# %% [markdown]
# What is the overall contractor sentiment?

# %%
sentiment_counts = df['cc_contractor_sentiment'].value_counts()
sentiment_counts
# Out:
# cc_contractor_sentiment
# Satisfied                                                                                                                                                                               15597
# Neutral                                                                                                                                                                                 12535
# Not Discussed                                                                                                                                                                            2290
# Dissatisfied                                                                                                                                                                              925
#  Chris                                                                                                                                                                                      4
#  can you hear me?"""                                                                                                                                                                        3
# Neutral/Dissatisfied                                                                                                                                                                        3
#  Owen                                                                                                                                                                                       2
#  which was supposed to be included in their public liability insurance."                                                                                                                    1
#  but there is no response or engagement from the agent."                                                                                                                                    1
#  without any further context or discussion."                                                                                                                                                1
#  indicating a potential connection issue or the start of the call."                                                                                                                         1
#  let's go"" twice without any clear topic or issue being discussed."                                                                                                                        1
#  but there is no response or further conversation."                                                                                                                                         1
#  come on."""                                                                                                                                                                                1
#  but there is no further conversation to analyze."                                                                                                                                          1
#  and no further dialogue or context is provided."                                                                                                                                           1
#  indicating a potential connection issue or a call that was not fully initiated."                                                                                                           1
#  indicating a potential connection issue."                                                                                                                                                  1
#  indicating a possible connection issue or a dropped call."                                                                                                                                 1
#  and the agent helped her understand the next steps."                                                                                                                                       1
#  and the agent explained that the company only requires a copy of the customer's existing insurance for their records."                                                                     1
#  Julian                                                                                                                                                                                     1
#  which the agent explained and clarified that his membership fee includes the accreditation. The agent then transferred Anthony to the renewal team to confirm the payment details."        1
#  and the agent assisted him with the request and offered additional help."                                                                                                                  1
#  and then confirming if the agent could hear them."                                                                                                                                         1
#  and the agent offered to investigate and resolve the issue."                                                                                                                               1
#  and the agent assisted her with the process."                                                                                                                                              1
#  what the hell? No?"""                                                                                                                                                                      1
#  despite having updated their documents. The agent helped resolve the issue and confirmed that everything was up-to-date on their end."                                                     1
#  which couldn't be used for another approval."                                                                                                                                              1
#  but was informed that it had expired and needed to be reinstated separately."                                                                                                              1
#  but the certificate doesn't reflect this change. The agent                                                                                                                                 1
#  despite having renewed their membership and uploaded insurance documents."                                                                                                                 1
#  despite having provided the necessary information."                                                                                                                                        1
#  and the agent assisted him with the upgrade and arranged for the audit team to contact him regarding the principal contractor addition."                                                   1
#  despite having up-to-date insurance documents. The agent helped resolve the issue by manually updating the insurance information."                                                         1
#  explaining the necessary steps and potential costs."                                                                                                                                       1
#  which was caused by a payment issue that was already resolved."                                                                                                                            1
#  which could simplify the accreditation process."                                                                                                                                           1
#  reducing the required documentation."                                                                                                                                                      1
#  and the agent                                                                                                                                                                              1
#  which the agent helped resolve by explaining that it was likely due to their insurance expiration date."                                                                                   1
#  and the agent helped him resolve the issue."                                                                                                                                               1
#  and the agent assisted her in resolving the issue."                                                                                                                                        1
#  and to resolve an issue with accessing the questionnaire."                                                                                                                                 1
#  despite having notified Safe Contractor that they would not be renewing their membership."                                                                                                 1
# "" to their accreditation certificate                                                                                                                                                       1
#  Rebecca                                                                                                                                                                                    1
#  Carly                                                                                                                                                                                      1
#  and the agent eventually responded with ""Can you hear me?"""                                                                                                                              1
#  Holly                                                                                                                                                                                      1
#  Jess                                                                                                                                                                                       1
#  as well as the New Building Safety Act section. The agent provided clarification and assistance."                                                                                          1
#  and the agent helped him troubleshoot the issue. The customer had completed all necessary steps but was still blocked                                                                      1
# Name: count, dtype: int64

# %%
sentiment_counts.plot(kind='bar', color='blue')
plt.title('Contractor Sentiment in Calls')
plt.xlabel('Sentiment')
plt.ylabel('Number of Calls')
plt.xticks(rotation=0)
plt.tight_layout()
plt.savefig('../../reports/figures/cc_02_sentiment.png')
plt.show()
# Out:
# C:\Users\Atharva\AppData\Local\Temp\ipykernel_3444\2022526909.py:6: UserWarning: Tight layout not applied. The left and right margins cannot be made large enough to accommodate all Axes decorations.
#   plt.tight_layout()

# %% [markdown]
# Was pricing mentioned in the call?

# %%
pricing_counts = df['cc_pricing_mentioned'].value_counts()
pricing_counts
# Out:
# cc_pricing_mentioned
# No     27509
# Yes     3897
# Name: count, dtype: int64

# %%
pricing_counts.plot(kind='bar', color=['red', 'blue'])
plt.title('Was Pricing Mentioned in the Call?')
plt.xlabel('')
plt.ylabel('Number of Calls')
plt.xticks(rotation=0)
plt.tight_layout()
plt.savefig('../../reports/figures/cc_03_pricing.png')
plt.show()

# %% [markdown]
# Did the contractor complain?

# %%
complaint_counts = df['cc_contractor_complained'].value_counts()
complaint_counts
# Out:
# cc_contractor_complained
# No     29193
# Yes     2213
# Name: count, dtype: int64

# %%
complaint_counts.plot(kind='bar', color=['steelblue', 'salmon'])
plt.title('Did the Contractor Complain?')
plt.xlabel('')
plt.ylabel('Number of Calls')
#plt.xticks(rotation=0)
plt.tight_layout()
plt.savefig('../../reports/figures/cc_03_complaints.png')
plt.show()
